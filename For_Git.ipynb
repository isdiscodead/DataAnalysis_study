# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
cd '/content/gdrive/MyDrive/Colab Notebooks/data_analysis_study/'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/data_analysis_study

# %%
# !echo "# 2022_data_analysis_study" >> README.md
# !git init
# !git config --global user.email "isdiscodead@korea.ac.kr"
# !git config --global user.name "isdiscodead"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://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@github.com/isdiscodead/2022_data_analysis_study.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/data_analysis_study/.git/
# [main 625aa3f] first commit
#  1 file changed, 1 insertion(+)
# fatal: remote origin already exists.
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 268 bytes | 67.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/isdiscodead/2022_data_analysis_study.git
#    48987a4..625aa3f  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git config --global user.email "isdiscodead@korea.ac.kr"
# !git config --global user.name "isdiscodead"
# !git add .
# !git commit -m "test"
# !git push origin main
# Out:
# [main 5333607] test
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  rename For_Git.ipynb => "For_Git.ipynb\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253" (100%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 505 bytes | 252.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/isdiscodead/2022_data_analysis_study.git
#    3de4308..5333607  main -> main
